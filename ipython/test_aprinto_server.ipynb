# %% [markdown]
# # Testing for APRINTO server

# %% [markdown]
# ## Load Libraries:

# %%
# Libraries
import pandas as pd
pd.set_option('expand_frame_repr',False)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width',180)
np = pd.np
np.set_printoptions(linewidth=200,threshold=np.nan)
from sqlalchemy import create_engine
engine = create_engine(r'postgresql://postgres:postgres@192.168.2.50:8800/routing',
                       encoding='utf-8',
                       echo=False)

from sys import argv
import json
from urllib2 import urlopen,Request
from poster.encode import multipart_encode
from poster.streaminghttp import register_openers
from uuid import uuid4 as get_guid
from datetime import datetime as DT
from uuid import getnode as get_mac

macs = {'Macbook':'105773427819682',
        'MacBookPro':'117637351435',}

this_mac = str(get_mac())

def post_json(all_data,p_url,show_post=False,show_resp=False):

    if show_post == True:
        print '\t\t\tJSON Posted:\n'
        print json.dumps(all_data, indent=4, sort_keys=True)

    json_data = json.dumps(all_data)
    headers = {'Content-type': 'application/json'}
    req = Request(p_url, json_data, headers)
    f = urlopen(req)
    response = f.read()
    f.close()

    if show_resp == True:
        parsed = json.loads(response)
        print '\t\t\tServer Response:\n'
        print json.dumps(parsed, indent=4, sort_keys=True)

    return response
def check(post_action='',show_info=False,show_post=False,show_resp=False):
    p_url = BASE_URL+'/api/check/'
    if show_info == True: print '\n\t\tTEST #1: printer driver check-in',post_action,'\n\t\t\tURL:',p_url
    guid = str(get_guid())
    data = [{
              'pdf_id' : guid,
              'printer_id' : 'printer_id1',
              'machine_id' : 'machine_id1',
              'application_name' : 'application_name1',
              'doc_name' : 'test_unit_1'
            }]

    resp = post_json(data,p_url,show_post,show_resp)
    if show_info == True: print '\n\t\t\t--> #1 SUCCESS\n'
    return guid
def upload_pdf(guid,uploadfile,upload_file_url,show_info=False,show_post=False,show_resp=False):
    if show_info == True: print '\t\tTEST #2: upload_pdf -->',uploadfile,'\n\n\t\t\tURL:',upload_file_url
    opener = register_openers()

    params = {'local_document': open(uploadfile,'rb'),
              'pdf_id' : guid}

    datagen, headers = multipart_encode(params)
    R = Request(upload_file_url, datagen, headers)

    if show_resp == True:
        print '\n\n\t\t\tURL Post Request:'
        print '\n\t\t\t\tHeaders:'
        print '\n\t\t\t\t\t',R.headers,'\n'
        print '\n\t\t\t\tParams:'
        print '\n\t\t\t\t\t',params,'\n'
        print '\t\t\t\tTotal Size:'
        print '\n\t\t\t\t\t',R.data.total,'\n'

    response = opener.open(R)

    if show_post == True:
        print '\n\t\t\tServer Response:'
        print '\n\t\t\t\t',response.read(),'\n'

    if show_info == True: print '\n\t\t\t--> #2 SUCCESS\n'
    return True
def upload_test(uploadfile,upload_file_url,show_info=False):
    guid = check(post_action='',show_info=show_info,show_post=show_info,show_resp=show_info)
    upload_pdf(guid,uploadfile,upload_file_url,show_info=show_info,show_post=show_info,show_resp=show_info)
    return True

# %% [markdown]
# ## Conduct Testing:

# %%
servers = pd.read_sql('select * from servers',engine)
TEST_TAG = 'aprinto'
BASE_URL = servers[servers.tag==TEST_TAG].ix[:,['web_service','location','port']]
BASE_URL = BASE_URL.apply(lambda s: str(s[0])+'://'+str(s[1])+':'+str(s[2]),axis=1).tolist()[0]

BASE_URL = 'http://printer.aporodelivery.com'

uploadfile='/Users/admin/Desktop/test.pdf'
upload_file_url=BASE_URL

show_info=False

if show_info==True:
    print '\n\tTesting "'+TEST_TAG+'"...\n'
    print '\tBase URL:',BASE_URL,'\n'

upload_test(uploadfile,upload_file_url,show_info=show_info)

if show_info==True: print '\n\tTesting COMPLETE\n'

# %%
# %timeit -n 1000 upload_test(uploadfile,upload_file_url,show_info=show_info)
# Out:
# 1000 loops, best of 3: 152 ms per loop

# %%
# !ab -kc 10 -n 1000 http://printer.aporodelivery.com/
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 655654 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking printer.aporodelivery.com (be patient)
# Completed 100 requests
# Completed 200 requests
# Completed 300 requests
# Completed 400 requests
# Completed 500 requests
# Completed 600 requests
# Completed 700 requests
# Completed 800 requests
# Completed 900 requests
# Completed 1000 requests
# Finished 1000 requests
#
#
# Server Software:        openresty/1.7.2.1
# Server Hostname:        printer.aporodelivery.com
# Server Port:            80
#
# Document Path:          /
# Document Length:        1494 bytes
#
# Concurrency Level:      10
# Time taken for tests:   8.431 seconds
# Complete requests:      1000
# Failed requests:        0
# Write errors:           0
# Keep-Alive requests:    0
# Total transferred:      1636000 bytes
# HTML transferred:       1494000 bytes
# Requests per second:    118.61 [#/sec] (mean)
# Time per request:       84.312 [ms] (mean)
# Time per request:       8.431 [ms] (mean, across all concurrent requests)
# Transfer rate:          189.49 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        0    2   0.3      2       3
# Processing:    16   82  45.7     76     434
# Waiting:       16   82  45.7     76     434
# Total:         18   84  45.7     78     436
#
# Percentage of the requests served within a certain time (ms)
#   50%     78
#   66%     99
#   75%    112
#   80%    119
#   90%    144
#   95%    165
#   98%    190
#   99%    207
#  100%    436 (longest request)

# %%
# !ab -kc 100 -n 1000 http://printer.aporodelivery.com/
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 655654 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking printer.aporodelivery.com (be patient)
# Completed 100 requests
# Completed 200 requests
# Completed 300 requests
# Completed 400 requests
# Completed 500 requests
# Completed 600 requests
# Completed 700 requests
# Completed 800 requests
# Completed 900 requests
# Completed 1000 requests
# Finished 1000 requests
#
#
# Server Software:        openresty/1.7.2.1
# Server Hostname:        printer.aporodelivery.com
# Server Port:            80
#
# Document Path:          /
# Document Length:        1494 bytes
#
# Concurrency Level:      100
# Time taken for tests:   8.411 seconds
# Complete requests:      1000
# Failed requests:        0
# Write errors:           0
# Keep-Alive requests:    0
# Total transferred:      1636000 bytes
# HTML transferred:       1494000 bytes
# Requests per second:    118.90 [#/sec] (mean)
# Time per request:       841.063 [ms] (mean)
# Time per request:       8.411 [ms] (mean, across all concurrent requests)
# Transfer rate:          189.96 [Kbytes/sec] received
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        1    2   0.6      2       4
# Processing:    60  802 140.8    826    1062
# Waiting:       60  802 140.8    826    1062
# Total:         63  804 140.4    827    1064
#
# Percentage of the requests served within a certain time (ms)
#   50%    827
#   66%    853
#   75%    867
#   80%    877
#   90%    904
#   95%    924
#   98%    949
#   99%    983
#  100%   1064 (longest request)

# %%
# from IPython.display import HTML
# r = urlopen('http://0.0.0.0:8080/').read()
# h = HTML(r); h

# %%
# !ab -n 1000 -kc 100 -p /Users/admin/Desktop/test.pdf http://printer.aporodelivery.com/
# Out:
# This is ApacheBench, Version 2.3 <$Revision: 655654 $>
# Copyright 1996 Adam Twiss, Zeus Technology Ltd, http://www.zeustech.net/
# Licensed to The Apache Software Foundation, http://www.apache.org/
#
# Benchmarking printer.aporodelivery.com (be patient)
# Completed 100 requests
# Completed 200 requests
# Completed 300 requests
# Completed 400 requests
# Completed 500 requests
# Completed 600 requests
# Completed 700 requests
# Completed 800 requests
# Completed 900 requests
# Completed 1000 requests
# Finished 1000 requests
#
#
# Server Software:        openresty/1.7.2.1
# Server Hostname:        printer.aporodelivery.com
# Server Port:            80
#
# Document Path:          /
# Document Length:        1690 bytes
#
# Concurrency Level:      100
# Time taken for tests:   22.990 seconds
# Complete requests:      1000
# Failed requests:        10
#    (Connect: 0, Receive: 0, Length: 10, Exceptions: 0)
# Write errors:           0
# Non-2xx responses:      10
# Keep-Alive requests:    3
# Total transferred:      1980466 bytes
# Total POSTed:           234991023
# HTML transferred:       1827080 bytes
# Requests per second:    43.50 [#/sec] (mean)
# Time per request:       2298.964 [ms] (mean)
# Time per request:       22.990 [ms] (mean, across all concurrent requests)
# Transfer rate:          84.13 [Kbytes/sec] received
#                         9982.03 kb/s sent
#                         10066.16 kb/s total
#
# Connection Times (ms)
#               min  mean[+/-sd] median   max
# Connect:        0 1016 601.3   1015    2088
# Processing:    67 1114 600.3   1119    2156
# Waiting:       44 1090 600.5   1095    2135
# Total:       2039 2130 274.5   2088    4208
#
# Percentage of the requests served within a certain time (ms)
#   50%   2088
#   66%   2100
#   75%   2102
#   80%   2110
#   90%   2157
#   95%   2157
#   98%   2516
#   99%   4160
#  100%   4208 (longest request)
